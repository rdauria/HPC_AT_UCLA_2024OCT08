# %% [markdown]
# ### Learning Outcomes 7
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>
#
# [7)](#Unix-command-line-101)  <a href="#/23/0">**unix command line 101**</a>
#
# [8)](#Getting-work-done-on-the-Hoffman2-Cluster)  <a href="#/32/0">Getting work done on the Hoffman2 Cluster</a>

# %% [markdown]
# # Unix command line 101
#
# https://www.hoffman2.idre.ucla.edu/Using-H2/Command-line/Unix-command-line.html
#
# ![Screen%20Shot%202022-02-08%20at%208.49.56%20PM.png](attachment:Screen%20Shot%202022-02-08%20at%208.49.56%20PM.png)

# %% [markdown]
# ## Unix command line 101: Navigation (Hands-on)
# https://www.hoffman2.idre.ucla.edu/Using-H2/Command-line/Unix-command-line.html#navigation
#
# - Try these commands:

# %%
ls
# Out:
# bash_example.ipynb
# bash-example.ipynb
# Batch_Jobs_on_H2C.ipynb
# Hands-on-command-line-and-modules.txt
# HOW_TO_VIEW_THESE_JUPYTER_NOTEBOOKS
# img/
# InteractiveComputingonH2C.ipynb
# INTRO_TO_H2C.ipynb
# julia-1.9-sample-notebook.ipynb
# Jupyter-on-H2C.ipynb
# LICENSE
# Plotting with python (matplotlib).ipynb
# R-approx-of-pi.ipynb
# R-benchmark-25.R
# README.md
# R_submit.sh
# test.png
# train_a_small_neural_network.ipynb
# train_one_neuron.ipynb@
# Unix_shell_and_enviornmental_modules.ipynb

# %%
ls -a
# Out:
# ./
# ../
# bash_example.ipynb
# bash-example.ipynb
# Batch_Jobs_on_H2C.ipynb
# .gitignore
# Hands-on-command-line-and-modules.txt
# HOW_TO_VIEW_THESE_JUPYTER_NOTEBOOKS
# img/
# InteractiveComputingonH2C.ipynb
# INTRO_TO_H2C.ipynb
# .ipynb_checkpoints/
# julia-1.9-sample-notebook.ipynb
# Jupyter-on-H2C.ipynb
# LICENSE
# Plotting with python (matplotlib).ipynb
# R-approx-of-pi.ipynb
# R-benchmark-25.R
# README.md
# R_submit.sh
# test.png
# train_a_small_neural_network.ipynb
# train_one_neuron.ipynb@
# Unix_shell_and_enviornmental_modules.ipynb

# %%
ls -lat
# Out:
# total 17273
# drwxr-xr-x. 2 dauria systems    4096 Oct  7 22:58 ./
# -rw-r--r--. 1 dauria systems 6601885 Oct  7 22:58 INTRO_TO_H2C.ipynb
# drwxr-xr-x. 2 dauria systems    4096 Oct  7 22:42 img/
# drwxr-xr-x. 2 dauria systems    4096 Oct  7 10:14 ../
# -rw-r--r--. 1 dauria systems    1025 Jun  5 18:01 HOW_TO_VIEW_THESE_JUPYTER_NOTEBOOKS
# -rw-r--r--. 1 dauria systems    1134 Jun  5 18:01 README.md
# -rw-r--r--. 1 dauria systems 2803076 Jun  5 17:53 Unix_shell_and_enviornmental_modules.ipynb
# drwxr-xr-x. 2 dauria systems    4096 Jun  5 17:20 .ipynb_checkpoints/
# -rw-r--r--. 1 dauria systems 1245453 Jun  5 17:15 InteractiveComputingonH2C.ipynb
# -rw-r--r--. 1 dauria systems 1974009 Jun  5 17:09 Jupyter-on-H2C.ipynb
# -rw-r--r--. 1 dauria systems 2542709 Jun  5 17:08 Batch_Jobs_on_H2C.ipynb
# -rw-r--r--. 1 dauria systems    1336 May 27 23:16 R_submit.sh
# -rw-r--r--. 1 dauria systems   13658 May 27 23:16 R-benchmark-25.R
# -rw-r--r--. 1 dauria systems   17715 Apr 30 17:30 test.png
# ...

# %%
ls -latr
# Out:
# total 17273
# -rw-r--r--. 1 dauria systems   35149 Apr  3  2024 LICENSE
# -rw-r--r--. 1 dauria systems    1363 Apr  3  2024 Hands-on-command-line-and-modules.txt
# -rw-r--r--. 1 dauria systems      18 Apr  3  2024 .gitignore
# -rw-r--r--. 1 dauria systems 2158726 Apr 15 20:12 train_a_small_neural_network.ipynb
# -rw-r--r--. 1 dauria systems  161021 Apr 16 13:43 Plotting with python (matplotlib).ipynb
# lrwxrwxrwx. 1 dauria systems      50 Apr 30 09:32 train_one_neuron.ipynb -> ../INTRO_TO_DEEP_LEARNING/Part 2 - Chapter 1.ipynb
# -rw-r--r--. 1 dauria systems   96230 Apr 30 15:14 R-approx-of-pi.ipynb
# -rw-r--r--. 1 dauria systems   25220 Apr 30 15:59 bash_example.ipynb
# -rw-r--r--. 1 dauria systems    1204 Apr 30 17:25 bash-example.ipynb
# -rw-r--r--. 1 dauria systems    1188 Apr 30 17:27 julia-1.9-sample-notebook.ipynb
# -rw-r--r--. 1 dauria systems   17715 Apr 30 17:30 test.png
# -rw-r--r--. 1 dauria systems   13658 May 27 23:16 R-benchmark-25.R
# ...

# %%
CURR_DIR=`pwd`; echo $CURR_DIR
# Out:
# /u/home/systems/dauria/JUPYTER_NOTEBOOKS/HPC_AT_UCLA_2024OCT08

# %%
cd $SCRATCH; pwd
# Out:
# /u/scratch/d/dauria

# %%
timestamp=`date "+%F_%H-%M"`; mkdir $HOME/HPC_at_UCLA_$timestamp; cd $HOME/HPC_at_UCLA_$timestamp

# %%
pwd
# Out:
# /u/home/systems/dauria/HPC_at_UCLA_2024-10-07_23-03

# %%
cd; rmdir $HOME/HPC_at_UCLA_$timestamp

# %%
ls $HOME/H2HH_$timestamp
# Out:
# ls: cannot access /u/home/systems/dauria/H2HH_2024-10-07_23-03: No such file or directory
# : 2

# %%
cd $CURR_DIR; pwd
# Out:
# /u/home/systems/dauria/JUPYTER_NOTEBOOKS/HPC_AT_UCLA_2024OCT08

# %% [markdown]
# ## Unix command line 101: Environmental Variables (Hands-on)
# https://www.hoffman2.idre.ucla.edu/Using-H2/Command-line/Unix-command-line.html#unix-environment-environmental-variables
#
# - Some important environmental variables:
#
# ```
# $PATH
# $LD_LIBRARY_PATH
# $HOME
# $SCRATCH  # Hoffman2-specific
# $SHELL
# ```
#
# - to check the content of an environmental variable issue:
#
# ```
# echo $HOME
# ```

# %% [markdown]
# ## Unix command line 101: Working with files (Hands-on)
# https://www.hoffman2.idre.ucla.edu/Using-H2/Command-line/Unix-command-line.html#working-with-files
#
# - Try these commands:
# ```
# cat $HOME/.bashrc
# less $HOME/.bashrc   # type q to interrupt
# more $HOME/.bashrc   # type q to interrupt
# ```
#
# - Check the first few lines of a file:
# ```
# head $HOME/.bash_profile
# head -n 2 $HOME/.bash_profile
# ```
#
# - Check the last few lines of a file:
# ```
# tail $HOME/.bash_profile
# tail -n 2 $HOME/.bash_profile
# ```
#
# - Check the last lines of a file as it is being written:
# ```
# tail -f $SGE_ROOT/$SGE_CELL/common/accounting   # Control-C to interrupt
# ```

# %%
cat $HOME/.bash_profile
# Out:
# # .bash_profile
#
# # Get the aliases and functions
# if [ -f ~/.bashrc ]; then
# 	. ~/.bashrc
# fi
#
# # User specific environment and startup programs
#
# PATH=$PATH:$HOME/.local/bin:$HOME/bin
#
# export PATH

# %%
head -n 2 $HOME/.bash_profile
# Out:
# # .bash_profile

# %%
tail -n 2 $HOME/.bash_profile

# %% [markdown]
# ## Unix command line 101: Editing files (Hands-on)
# https://www.hoffman2.idre.ucla.edu/Using-H2/Command-line/Unix-command-line.html#editing-files
#
# - Non graphical editors:
# ```
# nano
# emacs
# vi
# ```
#
# - Graphical editors:
# ```
# gedit &
# emacs &
# gvim &
# ```

# %% [markdown]
# ### Learning Outcomes 8
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>
#
# [7)](#Unix-command-line-101)  <a href="#/23/0">unix command line 101</a>
#
# [8)](#Getting-work-done-on-the-Hoffman2-Cluster)  <a href="#/32/0">**Getting work done on the Hoffman2 Cluster**</a>

# %% [markdown]
# # Getting work done on the cluster
#
# ![Screen%20Shot%202022-02-08%20at%209.39.32%20PM.png](attachment:Screen%20Shot%202022-02-08%20at%209.39.32%20PM.png)

# %% [markdown]
# # On which resources will your job run?
#
# https://www.hoffman2.idre.ucla.edu/Using-H2/Computing/Computing.html#computational-resources-on-the-hoffman2-cluster
#
# ## Highp vs shared vs campus resources:
# https://www.hoffman2.idre.ucla.edu/Using-H2/Computing/Computing.html#highp-vs-shared-vs-campus-jobs
#
# - `highp` refers to the use of group owned compute nodes
#   - users can run jobs for up to 14 days
#   - only for users in group who own resources
# - `shared` refers to the use of temporarely unused group owned compute nodes
#   - users can run jobs for up to 24 hours
#   - only for users in group who own resources
# - `campus` refers to compute nodes owned by IDRE and made available to the UCLA community
#   - users can run jobs for up to 24 hours

# %% [markdown]
# ## Do I have access to highp resources?
#
# To find out paste in a terminal connected to the clster the command (omitting the `$` character indicative of the unix prompt):
#
# `$ myresources`
#
# what do you see?

# %% [markdown]
# ## What computational resources do I have access to?
#
# Open a terminal on the Hoffman2 Cluster and issue:
#
# `$ myresources`
#
# **if** the first line of your ouput contains:
#
# `User joebruin is in the following resource group(s):  campus`
#
# you do NOT have access to group-owned compute nodes and can only run for up to 24 hours on nodes owned by OARC/IDRE
#
# **if** the first line of your output contains:
#
# `User joebruin is in the following resource group(s):  gobruins evebruin`
#
# you have access to the nodes purchased by groups: `gobruins` and `evebruin` and you can run for up to 24 hours on shared queues and for up to 14 days when requesting to run on owned resources (`highp` mode)

# %% [markdown]
# ## Working interactively on the Hoffman2 Cluster
#
# **More on this on future presentations**
#
# Any work that will use substantial computational resources should be run on [compute nodes](https://public.hoffman2.idre.ucla.edu/systems/5EHNT/INTRO_TO_H2C.slides.html#/2) and not on the [login nodes](https://www.hoffman2.idre.ucla.edu/Policies/Role-of-the-login-nodes.html).
#
# To get an *interactive session* on one core of a compute node, from a terminal issue the following command(omitting the `$` character indicative of the unix prompt):
#
# `
#   $ qrsh
# `
#
# What happens?
#
# (To terminate your interactive session, after the prompt returns, type: `Control` + `d` or `logout`)

# %% [markdown]
# ## What applications/software is already available on Hoffman2?
#
# Refer to: https://www.hoffman2.idre.ucla.edu/Using-H2/Software/Software.html
#
# ![Screenshot%202023-07-26%20at%209.34.40%20AM.png](attachment:Screenshot%202023-07-26%20at%209.34.40%20AM.png)

# %% [markdown]
# ### Apps available via modules
#
# To see what applications are available in the current hierarchy, at a terminal connected to Hoffman2 issue the command:
#
# `$ module av  # press enter to scroll down and exit the view`
#
# To look for a specific software, for example R, issue the command:
#
# `$ modules_lookup -m R`

# %% [markdown]
# # Worked out example of python environment creation
#
# - log onto the Hoffman2 Cluster via termina and SSH, at the cluster command prompt issue:
#
# ```
#  qrsh
#  module av python
#  module av anaconda
#  module av mamba
# ```
#
# - in this example we will use the default python version 3.9.6:
#
# ```
# module load python/3.9.6
# mkdir -p $HOME/.venv/3.9.6
# python -m venv $HOME/.venv/3.9.6/NEWENV
# source $HOME/.venv/3.9.6/NEWENV/bin/activate
# # now install any needed python package, for example:
# pip install numpy
# # for example, update pip:
# python -m pip install --upgrade pip
# ```
