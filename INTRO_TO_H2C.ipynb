# %% [markdown]
# #### HPC@UCLA: Introduction to the Hoffman2 Cluster
#
# ## Raffaella D'Auria, PhD
#
# ### Learning Outcomes
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>

# %% [markdown]
# # What is the Hoffman2 Cluster
#
# <img src="img/H2C.png" width="920" align="center" alt="Hoffman2 Cluster Cartoon"/>

# %% [markdown]
# - 800+ 64-bit nodes and over 26,000 cores
# - aggregate of over 174 TB of memory
# - each node has 1 GB Ethernet network and Infiniband interconnect
# - GPU nodes with computing capability ranging from 4 to 8.6
#
# ___
# For more info see: https://www.hoffman2.idre.ucla.edu/About/System-overview.html

# %% [markdown]
# # Nomenclature
#
# ## Compute node:
#
# - A compute node is a server (computer) with multiple computing cores that can execute as many simultaneous processes or threads as many cores it has
#
# ## Computing core:
#
# - A basic unit of computation within a CPU
#
# ## Login node:
#
# - A server designed to ensure connectivity between the "world" and the computing nodes on the cluster

# %% [markdown]
# # Nomenclature (cont'd)
#
# ## Computing Cluster:
#
# - A computing cluster is made of individual nodes (computers) which are interconnected between themselves and which aggregate power can be harnessed to address problems which nature requires either distributed or capacity computing

# %% [markdown]
# ### Learning Outcomes 2
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">**what can the Hoffman2 Cluster do for you**</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>

# %% [markdown]
# # What can the Hoffman2 Cluster do for you
#
# ## High Performance Computing
#
# - distributed computing (multiple computing cores across multiple compute nodes)
# - shared-memory computing (multiple cores on the same compute node)
# - data-intensive computing
# - high-memory computing
#
# ## Capacity Computing
#
# - multiple computing cores available to carry out very many simulations
# - execute concurrent (synchronous) or indeopendent (asynchronous) simulations

# %% [markdown]
# # What can the Hoffman2 Cluster do for you (cont'd)
#
# ## Licensed software availability
# - Abaqus
# - Intel Parallel Cluster Studio
# - Maple
# - Mathematica
# - MATLAB
#
# ## Licensed software management
#
# - bring your own licensed software (COMSOL, Ansys, FDTD, etc.)
#
# ## User Support/Project Collaboration/Training

# %% [markdown]
# ### Learning Outcomes 3
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">**navigating the documentation**</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>

# %% [markdown]
# # Navigating the documentation
#
# https://www.hoffman2.idre.ucla.edu/
#
# ![Screenshot%202024-10-07%20at%2011.14.43%E2%80%AFAM.png](attachment:Screenshot%202024-10-07%20at%2011.14.43%E2%80%AFAM.png)

# %% [markdown]
# ### Learning Outcomes 4
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">**getting an account on the Hoffman2 Cluster**</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster
#
# <img src="img/DEC.png" width="220" height="220" align="right" alt="DEC"/>
#
# - **WHO**
# - **WHAT**
# - **WHERE**
# - **WHY**
# - **HOW**
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster - WHO
#
#
# <img src="img/test-q1.png" width="220" height="220" align="right" alt="Puzzled Scientist"/>
#
# **WHO**: Any member of the UCLA community can get an account on the Hoffman2 Cluster

# %% [markdown]
# - perspective *Hoffman2 Cluster user* needs to be approved by a *Hoffman2 Cluster Faculty Sponsor*

# %% [markdown]
# - perspective *Hoffman2 Cluster Faculty Sponsor* any UCLA faculty or researchers that qualifies under [UCLA Policy 900](https://www.adminpolicies.ucla.edu/APP/Number/900) as principal investigators

# %% [markdown]
# - Hoffman2 Cluster Faculty Sponsors can sponsor themselves and their collaborators to become Hoffman2 Cluster users

# %% [markdown]
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster - WHAT
#
# <img src="img/test-a1.png" width="220" height="220" align="right" alt="Eureka moment"/>
#
# **WHAT**: A Hoffman2 Cluster account allows you to connect to the cluster and start computing on its resources

# %% [markdown]
# - A Hoffman2 Cluster Faculty Sponsor can:
#      - bestow access to the Hoffman2 Cluster and its computational resources to collaborators (e.g., students, researchers, staff)
#      - purchase additional computational resources such as compute nodes and/or storage
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster - WHERE
#
# - **WHERE**: All accounts matters are handled through the [System Identity Manager (SIM)](https://sim.idre.ucla.edu/) at https://sim.idre.ucla.edu/
#     - Access to SIM is via your [UCLA Logon ID](https://accounts.iam.ucla.edu/)
#
#        <img src="img/SIM_SINGLE_SIGNON.png" width="500" align="center" alt="SIM_SINGLE"/>
#
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster - WHY
#
# <img src="img/smart.png" width="220" height="220" align="right" alt="smart move"/>
#
# - **WHY**: Working on the Hoffman2 Cluster allows you to expand your computing capability
#     - You have reached the computing capability of your personal resources
#     - You would like to explore HPC/capacity computing in a supported environment
#     - The Hoffman2 Cluster is the UCLA research "cloud"
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster - HOW
#
# - **Connecting to SIM for the first time**:
#     - Demo Bruin requesting an account on the cluster
#
#     <img src="img/request_account_demo.png" width="700" align="center" alt="SIM_ACCOUNT"/>
#
#     - If you don't have yet an account on the cluster select "NO/I DO NOT KNOW"
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Getting an account on the Hoffman2 Cluster - HOW .
#
# - **Selecting a Hoffman2 Cluster Faculty Sponsor**:
#     - Demo Bruin wants to select Éuro Bruin as a H2C Faculty Sponsor
#
#     <img src="img/select_principal_investigator.png" width="700" align="center" alt="SIM_select_PI"/>
#
# - **Is Éuro Bruin a sponsor yet?**
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Registering with SIM as a Hoffman2 Faculty Sponsor
#
# **UCLA personnel who qualifies according to [UCLA Policy 900](https://www.adminpolicies.ucla.edu/APP/Number/900) as a primary investigator can apply to become Hoffman2 Cluster Faculty Sponsors**
#
# <img src="img/REGISTRATION-SIM-SPONSOR.png" width="700" align="center" alt="SIM_REGISTRATION_PI"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Registering with SIM as a Hoffman2 Faculty Sponsor (cont'd)
#
# Sponsors registration requires the creation of a [unix group](https://en.wikipedia.org/wiki/Group_identifier), all perspective users applying under a PI sponsorship will be part of this unix group.
#
# <img src="img/REQUEST_GROUP_SIM.png" width="700" align="center" alt="SIM_REQUEST_GROUP"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Registering with SIM as a Hoffman2 Faculty Sponsor (awaiting approval)
#
# - All Sponsors applications have to be verified and approved, this process generally take about a working day. After selecting the unix group name SIM will display:
#
#   <img src="img/awaiting_approval.png" width="700" align="center" alt="SIM_PI_APPROVAL_WAIT"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Registering with SIM as a Hoffman2 Faculty Sponsor - After Approval
#
# - Sponsor need to log back into SIM to check the status of their approval
# - after approval Sponsors can create an account for themselves and approve/deny new users requesting their sponsorship
#
#   <img src="img/create_an_account_euro.png" width="700" align="center" alt="SIM_CREATE_ACCOUNT"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Perspective user selecting a H2C Faculty Sponsor
#
# - **Demo Bruin is requsting an account under the sponsorsip of Éuro Bruin**
#
#   <img src="img/select_PI_euro.png" width="700" align="center" alt="SIM_REQUEST_ACCOUNT_WITH_PI"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Registering with SIM as a Hoffman2 Faculty Sponsor - Approve user account
#
# - **Sponsors need to approve accounts (even the one for themselves)**
#
#   <img src="img/request_PI_to_approve.png" width="700" align="center" alt="SIM_ASK_PI_TO_APPROVE_ACCOUNT"/>
#
# - **Demo Bruin should remind Éuro Bruin to log back on SIM to approve the new account**
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # H2C Faculty Sponsor approving/denying new accounts
#
# - **Sponsor Éuro Bruin now sees the request for account approval from Demo Bruin**
#
#   <img src="img/euro_approve_demo.png" width="700" align="center" alt="SIM_APPROVE_ACCOUNT_PI"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Setting the password for your account
#
# - Log back into SIM to check the status of your application, if approved you will see:
#
#   <img src="img/demo_set_password.png" width="700" align="center" alt="SIM_SET_PASSWORD"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Password resetting
#
# Navigate to: https://sim.idre.ucla.edu/sim/account/view and click on the link: `Change the password for <YOURHOFFMAN2USERNAME> on the H2 cluster` -- shown below for user `dbruin`.
#
# <img src="img/password_reset.png" width="700" align="center" alt="SIM_RESET_PASSWORD"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # New Password - Allow 30 minutes before logging into the cluster
#
# - After setting/resetting your password:
#
# <img src="img/demo_updated_password.png" width="700" align="center" alt="SIM_DISTRIBUTE_PASSWORD"/>
#
# ___
# More information are available at: https://www.hoffman2.idre.ucla.edu/Accounts/Accounts.html#

# %% [markdown]
# # Users responsibilities
#
# https://www.hoffman2.idre.ucla.edu/Policies/User-account-policy.html
#
# <img src="img/users_resp.png" width="700" align="center" alt="USER RESPONSIBILITIES"/>

# %% [markdown]
# ## Sponsor responsibilities
#
# https://www.hoffman2.idre.ucla.edu/Accounts/Sponsors-managing-your-group.html#sponsor-responsibilities
#
# <img src="img/sponsor_resp.png" width="700" align="center" alt="SPONSOR RESPONSIBILITIES"/>

# %% [markdown]
# # For sponsor: managing users in your group
#
# https://www.hoffman2.idre.ucla.edu/Accounts/Sponsors-managing-your-group.html#managing-your-users
#
# ![Screenshot%202023-10-10%20at%209.14.37%E2%80%AFPM.png](attachment:Screenshot%202023-10-10%20at%209.14.37%E2%80%AFPM.png)

# %% [markdown]
# ### Learning Outcomes 5
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">**connecting to the Hoffman2 Cluster via terminal and SSH**</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">opening graphical applications on the Hoffman2 Cluster</a>

# %% [markdown]
# # Connecting to the Hoffman2 Cluster via terminal and SSH
#
# https://www.hoffman2.idre.ucla.edu/Using-H2/Connecting/Connecting.html
#
# ![Screen%20Shot%202022-02-07%20at%204.55.02%20PM.png](attachment:Screen%20Shot%202022-02-07%20at%204.55.02%20PM.png)

# %% [markdown]
# # Connecting via a terminal and an SSH client (from Linux)
#
# https://www.hoffman2.idre.ucla.edu/Using-H2/Connecting/Connecting.html#connecting-via-terminal-and-ssh
#
# ![Screenshot%202024-04-02%20at%202.55.41%E2%80%AFPM.png](attachment:Screenshot%202024-04-02%20at%202.55.41%E2%80%AFPM.png)

# %% [markdown]
# # Connecting via a terminal and an SSH client (from Mac)
#
# https://www.hoffman2.idre.ucla.edu/Using-H2/Connecting/Connecting.html#connecting-via-terminal-and-ssh
#
# ![Screenshot%202024-04-02%20at%202.57.46%E2%80%AFPM.png](attachment:Screenshot%202024-04-02%20at%202.57.46%E2%80%AFPM.png)

# %% [markdown]
# # Connecting via a terminal and an SSH client (from Windows)
#
# https://www.hoffman2.idre.ucla.edu/Using-H2/Connecting/Connecting.html#connecting-via-terminal-and-ssh
#
# <img src="img/windows.png" width="700" align="center" alt="terminal from windows"/>

# %% [markdown]
# ## Connecting via terminal and SSH - Linux, Mac & Windows
#
#
# - on a Windows PowerShell make sure that the version is 5.1 or later with the command:
#
#  ```
#   $PSVersionTable.PSVersion
#  ```
#
# - on any terminal applications you may run (aside from Putty and Cygwin excluded in this presentation), type
#
#  ```
#   ssh <YOURHOFFMAN2CLUSTERUSERNAME>@hoffman2.idre.ucla.edu
#  ```

# %% [markdown]
# # Connecting via a terminal and SSH for the first time
#
# https://www.hoffman2.idre.ucla.edu/About/FAQ/FAQ.html#connecting-for-the-first-time
#
# ![WSL2_FIRST_TIME_LOGGING_IN.png](attachment:WSL2_FIRST_TIME_LOGGING_IN.png)

# %% [markdown]
# # Connecting for the first time hostkey fingerprints
#
# https://www.hoffman2.idre.ucla.edu/About/FAQ/FAQ.html#table-h2-public-host-classes
#
# ![WSL2-FIRST-TIME-SSH-HOST-FINGERPRINT-CHECK2.png](attachment:WSL2-FIRST-TIME-SSH-HOST-FINGERPRINT-CHECK2.png)

# %% [markdown]
# # Connecting via terminal and SSH (cont'd)
#
# ![WSL_Connected.png](attachment:WSL_Connected.png)

# %% [markdown]
# # Set up SSH keys to connect to the Hoffman2 Cluster
#
# SSH keys are authentication credentials that can be set up for passwordless authentication (**use of a passphrase is strongly recommended**).
#
# - On a terminal on your local computer generate SSH-key:
#
#  ```
#   ssh-keygen -f $HOME/.ssh/hoffman2.idre.ucla.edu
#  ```
#
# - On a terminal on your local computer create a ``$HOME/.ssh/config`` using, for example, the [nano](https://www.nano-editor.org/docs.php) editor:
#
#  ```
#   nano $HOME/.ssh/config
#  ```
#
# - **NOTE:** on a PowerShell terminal use instead:
#
#  ```
#   bash -c 'nano $HOME/.ssh/config'
#  ```

# %% [markdown]
# # Set up SSH keys to connect to the Hoffman2 Cluster (cont'd)
#
# - On a terminal on your local computer add these lines to your ``$HOME/.ssh/config``:
#
#  ```
#  Host hoffman2
#   hostname hoffman2.idre.ucla.edu
#   ServerAliveInterval 30
#   ServerAliveCountMax 5
#   IPQoS throughput
#   IdentityFile=~/.ssh/hoffman2.idre.ucla.edu
#  ```

# %% [markdown]
# # Set up SSH keys to connect to the Hoffman2 Cluster (cont'd 2)
#
# - copy the key to the Hoffman2 Cluster
#
# ```
#  $ ssh-copy-id -i ~/.ssh/hoffman2.idre.ucla.edu <H2C_USERNAME>@hoffman2.idre.ucla.edu
# ```
#
# - connect to the Hoffman2 Cluster
#
#  ```
#   $ ssh <H2C_LUSTERUSERNAME>@hoffman2
#  ```

# %% [markdown]
# ### Learning Outcomes 6
#
# [1)](#What-is-the-Hoffman2-Cluster) <a href="#/1/0">what is the Hoffman2 Cluster</a>
#
# [2)](#What-can-the-Hoffman2-Cluster-do-for-you) <a href="#/4/0">what can the Hoffman2 Cluster do for you</a>
#
# [3)](#Navigating-the-documentation) <a href="#/6/0">navigating the documentation</a>
#
# [4)](#Getting-an-account-on-the-Hoffman2-Cluster) <a href="#/8/0">getting an account on the Hoffman2 Cluster</a>
#
# [5)](#Connecting-to-the-Hoffman2-Cluster-via-terminal-and-SSH) <a href="#/12/0">connecting to the Hoffman2 Cluster via terminal and SSH</a>
#
# [6)](#Opening-graphical-applications-on-the-Hoffman2-Cluster)  <a href="#/18/0">**opening graphical applications on the Hoffman2 Cluster**</a>

# %% [markdown]
# # Opening graphical applications on the Hoffman2 Cluster
#
# **X Window Sytems/X11**: The software that allow displaying of graphical applications on a unix-like system and that is designed to work on a server-client mode (you can connect to it and forward graphical applications to your local computer)

# %% [markdown]
# ## Example: forward the MATLAB desktop GUI from Hoffman2 to your local computer
#
# ![Screen%20Shot%202022-02-07%20at%2011.23.57%20PM.png](attachment:Screen%20Shot%202022-02-07%20at%2011.23.57%20PM.png)

# %% [markdown]
# # Opening graphical applications on Linux (Hands-on)
#
#
# - [X11 server](https://www.x.org/wiki/) is natively available
# - forwarding of graphcail applications for remote display is enabled via:
# ```
# ssh -X joebruin@hoffman2.idre.ucla.edu
# ```
#   substitute `joebruin` with your Hoffman2 username

# %% [markdown]
# # Opening graphical applications on MacOS (Hands-on)
#
# ### first time only:
#
# - install [Xquartz](https://www.xquartz.org/) (the X11 server for MacOS)
# - open the terminal app and **before connecting to Hoffman2** issue:
#
# ```
# defaults write org.macosforge.xquartz.X11 enable_iglx -bool true
# ```
#
# - reboot your local computer
#
# ### connect with:
#
# - forwarding of graphcail applications for remote display is enabled via:
# ```
# ssh -Y joebruin@hoffman2.idre.ucla.edu
# ```
#   substitute `joebruin` with your Hoffman2 username

# %% [markdown]
# # Opening graphical applications on Windows
#
# ### no need to install other software then any of the following:
# - [MobaXterm](https://mobaxterm.mobatek.net/)
# - [Windows Subsystem for Linux](https://docs.microsoft.com/en-us/windows/wsl/install)
# - [Cygwin](https://www.cygwin.com/) - NOT RECOMMENDED UNLESS YOU ARE AN EXPERT
#
# ### need to install an X11 window server if using either of:
# - [GitBash](https://gitforwindows.org/)
# - [PuTTY](https://www.putty.org/)
# - [PowerShell](https://learn.microsoft.com/en-us/powershell/scripting/overview?view=powershell-7.4)
#
# #### a possible X11 Window server:
# - [Xming](http://www.straightrunning.com/XmingNotes/)

# %% [markdown]
# ## Opening graphical applications on Windows using MobaXterm (Hands-on)
#
# ![Screenshot%202022-02-08%20074952.png](attachment:Screenshot%202022-02-08%20074952.png)

# %% [markdown]
# ## Opening graphical applications on Windows using MobaXterm (cont'd)
#
# ![Screenshot%202022-02-08%20075046.png](attachment:Screenshot%202022-02-08%20075046.png)

# %% [markdown]
# ## Opening graphical applications on Windows using MobaXterm (cont'd)
#
# ![Screenshot%202022-02-08%20075130.png](attachment:Screenshot%202022-02-08%20075130.png)

# %% [markdown]
# ## Opening graphical applications on Windows using MobaXterm (cont'd)
#
# ![login.png](attachment:login.png)

# %% [markdown]
# ## Opening graphical applications on Windows using MobaXterm
#
# ![xclock.png](attachment:xclock.png)

# %% [markdown]
# # Conclusions
#
# <img src="img/taking-matters-into-hand.png" width="220" height="220"  align="right" alt="Taking matters into hands"/>
#
# - surveyed:
#   - what is the Hoffman2 Cluster & what it can do for you
#   - how/why to get an account/become a sponsor
#   - connect to the cluster via terminal and SSH
#   - opening graphical applications
#
#
#
# ___
# For more information see: https://www.hoffman2.idre.ucla.edu/

# %% [markdown]
# # Questions?

# %% [markdown]
# <img src="img/thanks.png" width="420" height="420"  align="center" alt="Thanks"/>
